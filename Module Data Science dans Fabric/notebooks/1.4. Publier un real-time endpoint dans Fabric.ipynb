# %% [markdown]
# # 1.4. Publier un real-time endpoint dans Fabric
# Ce notebook sert de support opératoire pour documenter la publication d'un endpoint temps réel depuis Fabric.

# %% [markdown]
# ## Étapes manuelles
# 1. Ouvrir le workspace [FORMATION].
# 2. Sélectionner le modèle ou l'artefact à publier.
# 3. Lancer la commande de publication du real-time endpoint.
# 4. Vérifier son apparition dans le workspace.
# 5. Tester le endpoint publié.

# %%
endpoint_name = "a_completer"
endpoint_url = "a_completer"
print("Completer ces valeurs apres publication :")
print({"endpoint_name": endpoint_name, "endpoint_url": endpoint_url})

# %%
# Optionnel: coller ici un exemple de test HTTP lorsque le endpoint est disponible
sample_payload = {"station": "Pont des Invalides", "jour": "2026-02-01", "heure": 8}
print(sample_payload)

# %% [markdown]
# ## À retenir
# La publication du real-time endpoint reste une étape majoritairement opératoire dans l'interface Fabric, mais ce notebook permet de centraliser les paramètres et le test d'usage.
# ## Exercice
# Compléter `endpoint_name` et `endpoint_url`, puis préparer un exemple de payload de test aligné sur votre modèle publié.
